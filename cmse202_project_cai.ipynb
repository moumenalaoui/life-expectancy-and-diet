# %% [markdown]
# vegetable oils vs life expectancy

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
life = pd.read_csv("life_expectancy.csv")
life
# Out:
#        #                   Country  Life Expectancy   (both sexes)  \
# 0      1                 Hong Kong                           85.29
# 1      2                     Japan                           85.03
# 2      3                     Macao                           84.68
# 3      4               Switzerland                           84.25
# 4      5                 Singapore                           84.07
# ..   ...                       ...                             ...
# 197  189              Sierra Leone                           55.92
# 198  190                   Nigeria                           55.75
# 199  191                   Lesotho                           55.65
# 200  192                      Chad                           55.17
# 201  193  Central African Republic                           54.36
#
#      Females   Life Expectancy  Males   Life Expectancy
# 0                        88.17                    82.38
# 1                        88.09                    81.91
# 2                        87.62                    81.73
# 3                        86.02                    82.42
# 4                        86.15                    82.06
# ..                         ...                      ...
# 197                      56.78                    55.01
# 198                      56.75                    54.80
# 199                      58.90                    52.52
# 200                      56.65                    53.73
# 201                      56.58                    52.16
#
# [202 rows x 5 columns]

# %%
# plot the data
fig = plt.figure(figsize=(30, 10))
plt.plot(life["Country"], life["Life Expectancy   (both sexes)"], marker='o', color='blue', linewidth=3)

# add title and axis labels
plt.title('Life Expectancy by Country')
plt.xlabel('Country')
plt.ylabel('Life Expectancy (both sexes)')


# rotate the x-axis labels for better visibility
plt.xticks(rotation=90)

# display the plot
plt.show()

# %%
# 读取数据集
life = pd.read_csv('life_expectancy.csv')
fat_sup = pd.read_csv("Fat_Supply_Quantity_Data.csv")

# 按国家合并数据集
merged_data = pd.merge(life, fat_sup, on="Country")

# 绘制散点图
fig, ax = plt.subplots(figsize=(10, 6))
ax.scatter(merged_data["Vegetable Oils"], merged_data["Life Expectancy   (both sexes)"], alpha=0.5)
ax.set_xlabel("Vegetable Oil Consumption (kg/capita/yr)")
ax.set_ylabel("Life Expectancy")
ax.set_title("Life Expectancy vs Vegetable Oil Consumption by Country")
plt.show()

# %%
#assume comsuming more oils would shorten the life expectancy
oil_sort = fat_sup.sort_values("Vegetable Oils",ascending=False)
oil_sort
# Out:
#           Country  Alcoholic Beverages  Animal Products  Animal fats  \
# 89        Liberia                  0.0           7.4228       0.4154
# 136  Sierra Leone                  0.0           5.9931       0.1678
# 134       Senegal                  0.0           6.1040       0.7876
# 40       Djibouti                  0.0          11.1065       1.3966
# 151          Togo                  0.0           5.3063       0.5351
# ..            ...                  ...              ...          ...
# 9      Azerbaijan                  0.0          32.1198       7.7987
# 142     Sri Lanka                  0.0          10.1348       0.3195
# 164       Vanuatu                  0.0          14.9179       1.9531
# 166       Vietnam                  0.0          33.2484       3.8238
# 95       Maldives                  0.0          29.7398       4.8409
#
#      Aquatic Products, Other  Cereals - Excluding Beer    Eggs  Fish, Seafood  \
# 89                       0.0                    3.3592  0.2528         0.3702
# 136                      0.0                    3.2063  0.2983         1.2117
# 134                      0.0                    5.7374  0.2580         0.7129
# 40                       0.0                    4.3977  0.2494         0.2910
# 151                      0.0                    8.9093  0.1962         0.5708
# ..                       ...                       ...     ...            ...
# 9                        0.0                    5.4481  2.0197         0.2122
# 142                      0.0                    2.7159  1.1682         2.2766
# 164                      0.0                    4.1249  0.3509         1.4343
# 166                      0.0                    3.7155  0.7839         1.1217
# 95                       0.0                    4.5092  3.2756         8.4068
#
#      Fruits - Excluding Wine     Meat  ...  Vegetable Oils  Vegetables  \
# 89                    0.1445   6.0051  ...         36.4186      0.1896
# 136                   0.2610   2.0412  ...         34.0479      0.2703
# 134                   0.0815   3.2319  ...         33.0391      0.1901
# 40                    0.1247   5.1210  ...         31.4490      0.4572
# 151                   0.0624   3.3889  ...         30.6430      0.1516
# ..                       ...      ...  ...             ...         ...
# 9                     0.5940  11.9993  ...          7.1538      0.6534
# 142                   0.5791   2.0270  ...          6.7000      0.2396
# 164                   0.3052   9.9334  ...          6.4849      0.1424
# 166                   0.4079  26.4292  ...          5.6211      0.6373
# 95                    0.4665   5.8360  ...          4.9549      0.5183
#
#      Obesity  Undernourished  Confirmed    Deaths  Recovered    Active  \
# 89       8.6            37.2   0.038671  0.001661   0.034994  0.002017
# 136      7.5            25.6   0.047286  0.000990   0.030738  0.015557
# 134      7.4            11.3   0.170145  0.004031   0.139107  0.027007
# 40      12.2            18.9   0.601316  0.006377   0.592308  0.002632
# 151      7.1            16.1   0.065660  0.000954   0.054777  0.009929
# ..       ...             ...        ...       ...        ...       ...
# 9       19.9            <2.5   2.285536  0.031223   2.225574  0.028740
# 142      5.4               9   0.312604  0.001600   0.285335  0.025669
# 164     23.5             7.2   0.000312  0.000000   0.000312  0.000000
# 166      2.1             9.3   0.002063  0.000036   0.001526  0.000501
# 95       7.9            10.3   3.078743  0.009982   2.690573  0.378189
#
#      Population  Unit (all except Population)
# 89    5058000.0                             %
# 136   7977000.0                             %
# 134  16744000.0                             %
# 40     988000.0                             %
# 151   8279000.0                             %
# ..          ...                           ...
# 9    10108000.0                             %
# 142  21937000.0                             %
# 164    321000.0                             %
# 166  96209000.0                             %
# 95     541000.0                             %
#
# [170 rows x 32 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 读取数据
fat_sup = pd.read_csv('Fat_Supply_Quantity_Data.csv')

# 根据国家分组并计算每个国家的平均值
grouped_data = data.groupby('Country')[['Life Expectancy   (both sexes)', 'Vegetable Oils']].mean()

# 绘制散点图
fig, ax = plt.subplots(figsize=(10, 6))
ax.scatter(grouped_data['Vegetable Products Supply Quantity (kg/capita/yr)'], grouped_data['Life expectancy '], alpha=0.5)
ax.set_xlabel('Vegetable Oil Consumption (kg/capita/yr)')
ax.set_ylabel('Life Expectancy')
ax.set_title('Life Expectancy vs Vegetable Oil Consumption by Country')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-72e360280149> in <module>
#       6
#       7 # 根据国家分组并计算每个国家的平均值
# ----> 8 grouped_data = data.groupby('Country')[['Life Expectancy   (both sexes)', 'Vegetable Oils']].mean()
#       9
#      10 # 绘制散点图
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in __getitem__(self, key)
#    1540                 stacklevel=2,
#    1541             )
# -> 1542         return super().__getitem__(key)
#    1543
#    1544     def _gotitem(self, key, ndim: int, subset=None):
#
# ~\anaconda3\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     266                     set(key).difference(self.obj.columns)  # type: ignore[attr-defined]
#     267                 )
# --> 268                 raise KeyError(f"Columns not found: {str(bad_keys)[1:-1]}")
#     269             return self._gotitem(list(key), ndim=2)
#     270
#
# KeyError: "Columns not found: 'Life Expectancy   (both sexes)'"

# %%
fig = plt.figure(figsize=(30, 10))
plt.xticks(rotation=90)
plt.plot(oil_sort["Country"],oil_sort["Vegetable Oils"])

# %%
# Load the data
df = pd.read_csv('Fat_Supply_Quantity_Data.csv')

# Create two scatter plots side-by-side
fig, axs = plt.subplots(1, 2, figsize=(12, 6))

# Plot 1: Vegetable oil consumption vs. country
axs[0].scatter(df['Country'], df['Vegetable Products'], alpha=0.5)
axs[0].set_xlabel('Country')
axs[0].set_ylabel('Vegetable Oil Consumption')
axs[0].set_title('Vegetable Oil Consumption by Country')

# Plot 2: Life expectancy vs. country
axs[1].scatter(df['Country'], df['Life expectancy '], alpha=0.5)
axs[1].set_xlabel('Country')
axs[1].set_ylabel('Life Expectancy')
axs[1].set_title('Life Expectancy by Country')

# Show the plots
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Vegetable Products'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-715454badf8b> in <module>
#       6
#       7 # Plot 1: Vegetable oil consumption vs. country
# ----> 8 axs[0].scatter(df['Country'], df['Vegetable Products'], alpha=0.5)
#       9 axs[0].set_xlabel('Country')
#      10 axs[0].set_ylabel('Vegetable Oil Consumption')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'Vegetable Products'

# %%
import seaborn as sns

# Load the data
df = 

# Create a scatter plot
sns.scatterplot(data=df, x='Vegetable Oils', y='Life expectancy ')

# Set the plot title and axis labels
plt.title('Vegetable Oil Consumption vs. Life Expectancy')
plt.xlabel('Vegetable Oil Consumption')
plt.ylabel('Life Expectancy')

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-cda225f22c5b> in <module>
#       5
#       6 # Create a scatter plot
# ----> 7 sns.scatterplot(data=df, x='Vegetable Oils', y='Life expectancy ')
#       8
#       9 # Set the plot title and axis labels
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#     799
#     800     variables = _ScatterPlotter.get_semantics(locals())
# --> 801     p = _ScatterPlotter(
#     802         data=data, variables=variables,
#     803         x_bins=x_bins, y_bins=y_bins,
#
# ~\anaconda3\lib\site-packages\seaborn\relational.py in __init__(self, data, variables, x_bins, y_bins, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend)
#     585         )
#     586
# --> 587         super().__init__(data=data, variables=variables)
#     588
#     589         self.alpha = alpha
#
# ~\anaconda3\lib\site-packages\seaborn\_core.py in __init__(self, data, variables)
#     602     def __init__(self, data=None, variables={}):
#     603
# --> 604         self.assign_variables(data, variables)
#     605
#     606         for var, cls in self._semantic_mappings.items():
#
# ~\anaconda3\lib\site-packages\seaborn\_core.py in assign_variables(self, data, variables)
#     665         else:
#     666             self.input_format = "long"
# --> 667             plot_data, variables = self._assign_variables_longform(
#     668                 data, **variables,
#     669             )
#
# ~\anaconda3\lib\site-packages\seaborn\_core.py in _assign_variables_longform(self, data, **kwargs)
#     900
#     901                 err = f"Could not interpret value `{val}` for parameter `{key}`"
# --> 902                 raise ValueError(err)
#     903
#     904             else:
#
# ValueError: Could not interpret value `Life expectancy ` for parameter `y`
